# %% [markdown]
# **Exploratory Data Analysis**

# %%
import pandas as pd
import openpyxl

data = pd.read_csv("data/NAICS_data_with_websites.csv")
data.head()
# Out:
#    Index                         INSURED_NM      INSURED_ADDR_LN_1  \
# 0     20  William Morris Home Fashions, Inc    1811 Crestwood Blvd
# 1     21     Alabama Policy Institute, Inc.        2213 Morris Ave
# 2     24                   Transformus, LLC      4701 Brigadoon Dr
# 3     25       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
# 4     26       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
#
#   INSURED_ADDR_LN_2 INSURED_CTY_NM INSURED_CNTY_NM INSURED_ST_CDE  \
# 0               NaN       Irondale       JEFFERSON             AL
# 1         1st Floor     Birmingham       JEFFERSON             AL
# 2               NaN         Durham          DURHAM             NC
# 3               NaN        Chicago            COOK             IL
# 4               NaN        Chicago            COOK             IL
#
#   INSURED_ZIP_CDE  NAICS Code  \
# 0           35210      423220
# 1           35203      541820
# 2           27705      711320
# 3           60632      722410
# 4           60632      722511
#
#                                    NAICS Description      Insured Website
# 0               Home Furnishing Merchant Wholesalers                  NaN
# 1                          Public Relations Agencies                  NaN
# 2  Promoters of Performing Arts, Sports, and Simi...                  NaN
# 3              Drinking Places (Alcoholic Beverages)  maddanthonysbar.com
# 4                           Full-Service Restaurants  maddanthonysbar.com

# %%
print(f"Total {len(data)} examples")
# Out:
# Total 110162 examples

# %%
print("Counts per NAICS codes in dataset:")
data["NAICS Code"].value_counts()
# Out:
# Counts per NAICS codes in dataset:
# NAICS Code
# 541611    5165
# 721110    4621
# 813990    4257
# 722511    3911
# 441110    2736
#           ...
# 316992       1
# 486110       1
# 313320       1
# 112410       1
# 212392       1
# Name: count, Length: 1066, dtype: int64

# %%
# Thre are 30,614 NaN Rows
data[data["NAICS Code"].isna()]
# Out:
# Empty DataFrame
# Columns: [Index, INSURED_NM, INSURED_ADDR_LN_1, INSURED_ADDR_LN_2, INSURED_CTY_NM, INSURED_CNTY_NM, INSURED_ST_CDE, INSURED_ZIP_CDE, NAICS Code, NAICS Description, Insured Website]
# Index: []

# %%
# Looking at the most common NAICS codes
data[data["NAICS Code"] == 441110.0].head()
# Out:
#      Index                                         INSURED_NM  \
# 18      46                                   Gross Motors Inc
# 51      84                     BOB HOWARD ENGLISH IMPORTS LLC
# 61      95                                 Keystone Chevrolet
# 177    223  Saturn of Permian Basin, Inc. dba Mazda of Mid...
# 185    231                        Ram Motors Auto Sales, Inc.
#
#               INSURED_ADDR_LN_1 INSURED_ADDR_LN_2 INSURED_CTY_NM  \
# 18     404 East Division Street               NaN    Neillsville
# 51           17970 Gulf Freeway               NaN    Friendswood
# 61       8700 Charles Page Blvd               NaN   Sand Springs
# 177    5115 West Loop 250 North               NaN        Midland
# 185  4537 Arrowhead Ridge Dr SE               NaN     Rio Rancho
#
#     INSURED_CNTY_NM INSURED_ST_CDE INSURED_ZIP_CDE  NAICS Code  \
# 18            CLARK             WI           54456      441110
# 51        GALVESTON             TX           77546      441110
# 61            TULSA             OK           74063      441110
# 177         MIDLAND             TX           79707      441110
# 185        SANDOVAL             NM           87124      441110
#
#     NAICS Description         Insured Website
# 18    New Car Dealers       www.grossauto.com
# 51    New Car Dealers                     NaN
# 61    New Car Dealers   keystonechevrolet.com
# 177   New Car Dealers  www.mazdaofmidland.com
# 185   New Car Dealers           rammotors.net

# %% [markdown]
# Most common NAICS Codes:
# 1. Administrative Management and General Manageme...
# 2. Hotels (except Casino Hotels) and Motels
# 3. Other Similar Organizations (except Business, ...
# 4. Full-Service Restaurants
# 5. New Car Dealers

# %% [markdown]
# **Data Cleaning**

# %%
# Removing all rows with NaNs in NAICS Code
cleaned_data = data.dropna(subset=["NAICS Code"])

# %%
cleaned_data.head()
# Out:
#    Index                         INSURED_NM      INSURED_ADDR_LN_1  \
# 0     20  William Morris Home Fashions, Inc    1811 Crestwood Blvd
# 1     21     Alabama Policy Institute, Inc.        2213 Morris Ave
# 2     24                   Transformus, LLC      4701 Brigadoon Dr
# 3     25       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
# 4     26       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
#
#   INSURED_ADDR_LN_2 INSURED_CTY_NM INSURED_CNTY_NM INSURED_ST_CDE  \
# 0               NaN       Irondale       JEFFERSON             AL
# 1         1st Floor     Birmingham       JEFFERSON             AL
# 2               NaN         Durham          DURHAM             NC
# 3               NaN        Chicago            COOK             IL
# 4               NaN        Chicago            COOK             IL
#
#   INSURED_ZIP_CDE  NAICS Code  \
# 0           35210      423220
# 1           35203      541820
# 2           27705      711320
# 3           60632      722410
# 4           60632      722511
#
#                                    NAICS Description      Insured Website
# 0               Home Furnishing Merchant Wholesalers                  NaN
# 1                          Public Relations Agencies                  NaN
# 2  Promoters of Performing Arts, Sports, and Simi...                  NaN
# 3              Drinking Places (Alcoholic Beverages)  maddanthonysbar.com
# 4                           Full-Service Restaurants  maddanthonysbar.com

# %%
cleaned_data["INSURED_ST_CDE"].value_counts()
# Out:
# INSURED_ST_CDE
# FL    10054
# TX     9836
# CA     7500
# AL     4916
# NY     4797
# IL     4750
# MA     4593
# AZ     4486
# GA     4163
# NJ     4015
# PA     3630
# CT     3236
# CO     3219
# MI     2449
# WA     2189
# TN     2143
# OH     2038
# NC     1802
# MO     1726
# MD     1611
# VA     1519
# OR     1474
# MS     1451
# UT     1446
# WI     1418
# MN     1324
# IN     1259
# AR     1253
# NE     1198
# NV     1153
# KS     1080
# NM     1066
# SC     1003
# DE      931
# ME      871
# OK      859
# ID      855
# MT      854
# NH      827
# VT      663
# IA      650
# KY      570
# RI      556
# DC      503
# HI      417
# LA      409
# WV      391
# SD      387
# WY      364
# ND      181
# AK       69
# Mi        4
# al        2
# Ut        1
# Tx        1
# Name: count, dtype: int64

# %%
# Some state examples are lowercased
cleaned_data["INSURED_ST_CDE"] = cleaned_data["INSURED_ST_CDE"].str.upper()

# %%
cleaned_data["INSURED_ST_CDE"].value_counts()
# Out:
# INSURED_ST_CDE
# FL    10054
# TX     9837
# CA     7500
# AL     4918
# NY     4797
# IL     4750
# MA     4593
# AZ     4486
# GA     4163
# NJ     4015
# PA     3630
# CT     3236
# CO     3219
# MI     2453
# WA     2189
# TN     2143
# OH     2038
# NC     1802
# MO     1726
# MD     1611
# VA     1519
# OR     1474
# MS     1451
# UT     1447
# WI     1418
# MN     1324
# IN     1259
# AR     1253
# NE     1198
# NV     1153
# KS     1080
# NM     1066
# SC     1003
# DE      931
# ME      871
# OK      859
# ID      855
# MT      854
# NH      827
# VT      663
# IA      650
# KY      570
# RI      556
# DC      503
# HI      417
# LA      409
# WV      391
# SD      387
# WY      364
# ND      181
# AK       69
# Name: count, dtype: int64

# %%
# Renaming columns for consistency
cleaned_data = cleaned_data.rename(columns={"INSURED_NM" : "Business_Name"})
cleaned_data = cleaned_data.rename(columns={"NAICS Code" : "NAICS_Code"})
cleaned_data = cleaned_data.rename(columns={"NAICS Description" : "NAICS_Description"})

# %%
cleaned_data.head()
# Out:
#    Index                      Business_Name      INSURED_ADDR_LN_1  \
# 0     20  William Morris Home Fashions, Inc    1811 Crestwood Blvd
# 1     21     Alabama Policy Institute, Inc.        2213 Morris Ave
# 2     24                   Transformus, LLC      4701 Brigadoon Dr
# 3     25       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
# 4     26       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
#
#   INSURED_ADDR_LN_2 INSURED_CTY_NM INSURED_CNTY_NM INSURED_ST_CDE  \
# 0               NaN       Irondale       JEFFERSON             AL
# 1         1st Floor     Birmingham       JEFFERSON             AL
# 2               NaN         Durham          DURHAM             NC
# 3               NaN        Chicago            COOK             IL
# 4               NaN        Chicago            COOK             IL
#
#   INSURED_ZIP_CDE  NAICS_Code  \
# 0           35210      423220
# 1           35203      541820
# 2           27705      711320
# 3           60632      722410
# 4           60632      722511
#
#                                    NAICS_Description      Insured Website
# 0               Home Furnishing Merchant Wholesalers                  NaN
# 1                          Public Relations Agencies                  NaN
# 2  Promoters of Performing Arts, Sports, and Simi...                  NaN
# 3              Drinking Places (Alcoholic Beverages)  maddanthonysbar.com
# 4                           Full-Service Restaurants  maddanthonysbar.com

# %%
cleaned_data = cleaned_data.fillna('')

# Create the unified address column
cleaned_data['FULL_ADDRESS'] = (
    cleaned_data['INSURED_ADDR_LN_1'].str.strip() + ' ' + 
    cleaned_data['INSURED_ADDR_LN_2'].str.strip() + ', ' + 
    cleaned_data['INSURED_CTY_NM'].str.strip() + ', ' + 
    cleaned_data['INSURED_ST_CDE'].str.strip() + ' ' + 
    cleaned_data['INSURED_ZIP_CDE'].astype(str).str.strip()
)

# Clean up double commas if Address Line 2 was empty
cleaned_data['FULL_ADDRESS'] = cleaned_data['FULL_ADDRESS'].str.replace(', ,', ',').str.strip()
cleaned_data.head()
# Out:
#    Index                      Business_Name      INSURED_ADDR_LN_1  \
# 0     20  William Morris Home Fashions, Inc    1811 Crestwood Blvd
# 1     21     Alabama Policy Institute, Inc.        2213 Morris Ave
# 2     24                   Transformus, LLC      4701 Brigadoon Dr
# 3     25       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
# 4     26       Lacoco's Pizza & Pasta, Inc.  3350 West 47th Street
#
#   INSURED_ADDR_LN_2 INSURED_CTY_NM INSURED_CNTY_NM INSURED_ST_CDE  \
# 0                         Irondale       JEFFERSON             AL
# 1         1st Floor     Birmingham       JEFFERSON             AL
# 2                           Durham          DURHAM             NC
# 3                          Chicago            COOK             IL
# 4                          Chicago            COOK             IL
#
#   INSURED_ZIP_CDE  NAICS_Code  \
# 0           35210      423220
# 1           35203      541820
# 2           27705      711320
# 3           60632      722410
# 4           60632      722511
#
#                                    NAICS_Description      Insured Website  \
# 0               Home Furnishing Merchant Wholesalers
# 1                          Public Relations Agencies
# 2  Promoters of Performing Arts, Sports, and Simi...
# 3              Drinking Places (Alcoholic Beverages)  maddanthonysbar.com
# 4                           Full-Service Restaurants  maddanthonysbar.com
#
#                                       FULL_ADDRESS
# 0         1811 Crestwood Blvd , Irondale, AL 35210
# 1  2213 Morris Ave 1st Floor, Birmingham, AL 35203
# 2             4701 Brigadoon Dr , Durham, NC 27705
# 3        3350 West 47th Street , Chicago, IL 60632
# 4        3350 West 47th Street , Chicago, IL 60632

# %%
cleaned_data = cleaned_data.drop(columns=["Index", "INSURED_ADDR_LN_1", "INSURED_ADDR_LN_2", "INSURED_CTY_NM", "INSURED_CNTY_NM", "INSURED_ST_CDE", "INSURED_ZIP_CDE"])

# %%
cleaned_data.to_csv("data/cleaned_data.csv", index=False)

# %% [markdown]
# Prep for multi-head architecture

# %%
# Add input column for single encoder
cleaned_data['inputs'] = (
        "BUSINESS: " + cleaned_data['Business_Name'].astype(str) + 
        " | ADDRESS: " + cleaned_data['FULL_ADDRESS'].astype(str)
    )

# %%
# Ensure the column is string-type and padded (NAICS can sometimes lose leading zeros)
cleaned_data["NAICS_Code"] = cleaned_data["NAICS_Code"].astype(str).str.zfill(6)

# Extract the hierarchical levels
cleaned_data['sector_label'] = cleaned_data['NAICS_Code'].str[:2]    # 2-digit (e.g., 44)
cleaned_data['subsector_label'] = cleaned_data['NAICS_Code'].str[:3] # 3-digit (e.g., 441)
cleaned_data['industry_label'] = cleaned_data['NAICS_Code'].str[:6]          # 6-digit (e.g., 441320)

# %% [markdown]
# The following are the class counts used for the model arch

# %%
# Count number of unique codes at each level
print(f"Unique 2-digit sectors: {cleaned_data['sector_label'].nunique()}")
print(f"Unique 3-digit subsectors: {cleaned_data['subsector_label'].nunique()}")
print(f"Unique 6-digit industries: {cleaned_data['industry_label'].nunique()}")
# Out:
# Unique 2-digit sectors: 24
# Unique 3-digit subsectors: 98
# Unique 6-digit industries: 1066

# %%
from sklearn.model_selection import train_test_split

# Handle singletons (codes appearing only once)
counts = cleaned_data['NAICS_Code'].value_counts()
singletons = counts[counts == 1].index
df_multi = cleaned_data[~cleaned_data['NAICS_Code'].isin(singletons)]
df_single = cleaned_data[cleaned_data['NAICS_Code'].isin(singletons)]

# Split: Separate the 20% TEST set
# Remaining 80% will be used for Train + Val
train_val, test = train_test_split(
    df_multi, 
    test_size=0.20, 
    random_state=101, 
    stratify=df_multi['NAICS_Code']
)

# Second Split: Split the 80% into Train (70% total) and Val (10% total)
# Calculation: 0.10 / 0.80 = 0.125
train, val = train_test_split(
    train_val, 
    test_size=0.125, 
    random_state=101, 
    stratify=train_val['NAICS_Code']
)

# Add singletons to Training (They must be seen during training)
train = pd.concat([train, df_single])

print(f"Final Split Counts:\nTrain: {len(train)}\nVal: {len(val)}\nTest: {len(test)}")
# Out:
# Final Split Counts:
# Train: 77129
# Val: 11011
# Test: 22022

# %%
train.to_csv("data/split_data/train.csv", index=False)
val.to_csv("data/split_data/val.csv", index=False)
test.to_csv("data/split_data/test.csv", index=False)

# %%
scraped = pd.read_csv("data/website_summaries.csv")
scraped.head(10)
# Out:
#    Index                               INSURED_NM  \
# 0     20        William Morris Home Fashions, Inc
# 1     21           Alabama Policy Institute, Inc.
# 2     24                         Transformus, LLC
# 3     25             Lacoco's Pizza & Pasta, Inc.
# 4     26             Lacoco's Pizza & Pasta, Inc.
# 5     27                         Henig Furs, Inc.
# 6     30  Seoyon E-HWA Manufacturing Auburn, Inc.
# 7     31  Seoyon E-HWA Manufacturing Auburn, Inc.
# 8     33              Ian Garinger Consulting LLC
# 9     34                  Danson Construction LLC
#
#              INSURED_ADDR_LN_1 INSURED_ADDR_LN_2 INSURED_CTY_NM  \
# 0          1811 Crestwood Blvd               NaN       Irondale
# 1              2213 Morris Ave         1st Floor     Birmingham
# 2            4701 Brigadoon Dr               NaN         Durham
# 3        3350 West 47th Street               NaN        Chicago
# 4        3350 West 47th Street               NaN        Chicago
# 5         4135 Carmichael Road               NaN     Montgomery
# 6  217 Thweatt Industrial Blvd               NaN      Dadeville
# 7  217 Thweatt Industrial Blvd               NaN      Dadeville
# 8              20 Pennbrook Ct               NaN        Boonton
# 9     2624 W Lone Cactus Drive               NaN        Phoenix
#
#   INSURED_CNTY_NM INSURED_ST_CDE INSURED_ZIP_CDE  NAICS Code  \
# 0       JEFFERSON             AL           35210      423220
# 1       JEFFERSON             AL           35203      541820
# 2          DURHAM             NC           27705      711320
# 3            COOK             IL           60632      722410
# 4            COOK             IL           60632      722511
# 5      MONTGOMERY             AL           36106      448190
# 6      TALLAPOOSA             AL           36853      336390
# 7      TALLAPOOSA             AL           36853      336112
# 8          MORRIS             NJ            7005      541512
# 9        MARICOPA             AZ           85027      236220
#
#                                    NAICS Description  \
# 0               Home Furnishing Merchant Wholesalers
# 1                          Public Relations Agencies
# 2  Promoters of Performing Arts, Sports, and Simi...
# 3              Drinking Places (Alcoholic Beverages)
# 4                           Full-Service Restaurants
# 5                              Other Clothing Stores
# 6            Other Motor Vehicle Parts Manufacturing
# 7      Light Truck and Utility Vehicle Manufacturing
# 8                   Computer Systems Design Services
# 9  Commercial and Institutional Building Construc...
#
#               Insured Website  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3         maddanthonysbar.com
# 4         maddanthonysbar.com
# 5  https://www.henigfurs.com/
# 6                belite.co.kr
# 7                belite.co.kr
# 8                         NaN
# 9              dansonbldg.com
#
#                                         scraped_text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Layaway & Interest-Free Financing Options Avai...
# 6  메뉴 바로가기 본문 바로가기 회사소개 회사개요 연혁 핵심가치 CSR ESG 정책 법...
# 7  메뉴 바로가기 본문 바로가기 회사소개 회사개요 연혁 핵심가치 CSR ESG 정책 법...
# 8                                                NaN
# 9  It’s our mission to make clients for life by u...
#
#                                              summary
# 0                  Insufficient content for summary.
# 1                  Insufficient content for summary.
# 2                  Insufficient content for summary.
# 3                  Insufficient content for summary.
# 4                  Insufficient content for summary.
# 5  Up to 80% off sitewide with extra 20% at check...
# 6  Kwangsun Corporation operates globally with su...
# 7  Kwangsun Corporation operates global subsidiar...
# 8                  Insufficient content for summary.
# 9  Danson Construction focuses on long-term clien...
