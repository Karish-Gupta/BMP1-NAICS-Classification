# %%
import pandas as pd
import math

def split_unprocessed_data(input_file, chunk_size=10000):
   print(f"Loading {input_file}...")
   
   try:
      # Load the CSV using the python engine to bypass buffer limits
      df = pd.read_csv(
         input_file, 
         encoding='latin-1', 
         engine='python',       # Swaps to the more robust parsing engine
      )
   except Exception as e:
      print(f"Failed to load CSV. Error: {e}")
      return

   # Ensure 'summary' exists to prevent KeyError
   if 'summary' not in df.columns:
      df['summary'] = None

   # FIND STARTING INDICES (Now only checking 'summary' since 'scraped_text' is gone)
   empty_mask = (df['summary'].isna() | (df['summary'].astype(str).str.strip() == ""))
   
   # Check if we actually have any rows matching the condition
   if not empty_mask.any():
      print("No rows found with an empty 'summary'. Exiting.")
      return

   # Find the index of the first occurrence
   start_index = empty_mask.idxmax()
   total_unprocessed = len(df) - start_index
   
   print(f"Found the first empty row at index {start_index}.")
   print(f"Total unprocessed rows to chunk: {total_unprocessed}")
   
   # Slice the dataframe starting from the first empty row
   df_unprocessed = df.iloc[start_index:]
   
   # Split and save into chunks
   num_chunks = math.ceil(len(df_unprocessed) / chunk_size)
   
   for i in range(num_chunks):
      # Calculate row boundaries for the current chunk
      start_row = i * chunk_size
      end_row = start_row + chunk_size
      
      # Extract the chunk
      chunk = df_unprocessed.iloc[start_row:end_row]
      
      # Save to a new CSV file (forcing utf-8 so the new files are clean)
      output_filename = f'unprocessed_data_part_{i+1}.csv'
      chunk.to_csv(output_filename, index=False, encoding='utf-8')
      print(f"Saved: {output_filename} ({len(chunk)} rows)")

   print("\nSplitting complete!")

# --- Execute the script ---
# Replace 'your_data.csv' with the actual name of your CSV file
split_unprocessed_data('website_summaries_train.csv')
# Out:
# Loading website_summaries_train.csv...
# Found the first empty row at index 22.
# Total unprocessed rows to chunk: 77107
# Saved: unprocessed_data_part_1.csv (10000 rows)
# Saved: unprocessed_data_part_2.csv (10000 rows)
# Saved: unprocessed_data_part_3.csv (10000 rows)
# Saved: unprocessed_data_part_4.csv (10000 rows)
# Saved: unprocessed_data_part_5.csv (10000 rows)
# Saved: unprocessed_data_part_6.csv (10000 rows)
# Saved: unprocessed_data_part_7.csv (10000 rows)
# Saved: unprocessed_data_part_8.csv (7107 rows)
#
# Splitting complete!

# %%
import pandas as pd

# Create list of file names in correct order
files = [f"website_summaries_train_part_{i}.csv" for i in range(1, 9)]

# Read and combine
df = pd.concat([pd.read_csv(file) for file in files], ignore_index=True)

# Save to a new CSV
df.to_csv("website_summaries_full.csv", index=False)

print("Combined file saved as website_summaries_full.csv")
# Out:
# Combined file saved as website_summaries_full.csv

# %%
full_data = pd.read_csv("website_summaries_full.csv")
full_data.head()
# Out:
#                                        Business_Name  NAICS_Code  \
# 0                   High Country Tires & Auto Repair      441320
# 1                        Enthuse Marketing Group LLC      541614
# 2  Lawson Family Ventures, LLC dba Crafted Custom...      236115
# 3                              GNI Pocono Eagle, Inc      923110
# 4                  Baron Hoover, LLC dba Hyatt Place      721110
#
#                                    NAICS_Description  \
# 0                                       Tire Dealers
# 1  Process, Physical Distribution, and Logistics ...
# 2  New Single-Family Housing Construction (except...
# 3               Administration of Education Programs
# 4           Hotels (except Casino Hotels) and Motels
#
#             Insured Website  \
# 0         www.bigotires.com
# 1  www.inspiramarketing.com
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                         FULL_ADDRESS  \
# 0          7690 E Hwy 69 , Prescott Valley, AZ 86314
# 1            50 Washington Street , Norwalk, CT 6854
# 2            5323 Gulfton Street , Houston, TX 77081
# 3  3455 Northeast 12th Terrace Suite 12, Oakland ...
# 4   2980 John Hawkins Parkway , Birmingham, AL 35244
#
#                                               inputs  sector_label  \
# 0  BUSINESS: High Country Tires & Auto Repair | A...            44
# 1  BUSINESS: Enthuse Marketing Group LLC | ADDRES...            54
# 2  BUSINESS: Lawson Family Ventures, LLC dba Craf...            23
# 3  BUSINESS: GNI Pocono Eagle, Inc | ADDRESS: 345...            92
# 4  BUSINESS: Baron Hoover, LLC dba Hyatt Place | ...            72
#
#    subsector_label  industry_label  \
# 0              441          441320
# 1              541          541614
# 2              236          236115
# 3              923          923110
# 4              721          721110
#
#                                              summary
# 0  Big O Tires sells tires and provides automotiv...
# 1  They create live experiences to foster long-te...
# 2                  Insufficient content for summary.
# 3                  Insufficient content for summary.
# 4                  Insufficient content for summary.

# %%
len(full_data[full_data["summary"] == "Insufficient content for summary."])
# Out:
# 46402

# %%
full_data["summary"] = full_data["summary"].replace(
    "Insufficient content for summary.", ""
)

full_data.to_csv("website_summaries_full.csv", index=False)
